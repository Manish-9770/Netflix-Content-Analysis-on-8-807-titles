# %% [markdown]
#  # Import all the Required Libraries

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 
import sklearn
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Read and look the data

# %%
#Read and Look the Data
df = pd.read_csv('netflix_titles.csv')
print(df)
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
# To Show the Nummber Of rows and Column
df.head(10)
# Out:
#   show_id     type                             title  \
# 0      s1    Movie              Dick Johnson Is Dead
# 1      s2  TV Show                     Blood & Water
# 2      s3  TV Show                         Ganglands
# 3      s4  TV Show             Jailbirds New Orleans
# 4      s5  TV Show                      Kota Factory
# 5      s6  TV Show                     Midnight Mass
# 6      s7    Movie  My Little Pony: A New Generation
# 7      s8    Movie                           Sankofa
# 8      s9  TV Show     The Great British Baking Show
# 9     s10    Movie                      The Starling
#
#                         director  \
# 0                Kirsten Johnson
# 1                            NaN
# 2                Julien Leclercq
# 3                            NaN
# 4                            NaN
# 5                  Mike Flanagan
# 6  Robert Cullen, José Luis Ucha
# 7                   Haile Gerima
# 8                Andy Devonshire
# 9                 Theodore Melfi
#
# ...

# %%
# Check the Data Type
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
# To Show the Number of rows & column
df.shape
# Out:
# (8807, 12)

# %%
# to see the column names
df.columns.values
# Out:
# array(['show_id', 'type', 'title', 'director', 'cast', 'country',
#        'date_added', 'release_year', 'rating', 'duration', 'listed_in',
#        'description'], dtype=object)

# %% [markdown]
# ## To Check the missing values

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %% [markdown]
# ## To fill the missing values

# %%
df['director'] = df['director'].ffill()
df['cast'] = df['cast'].ffill()
df['country'] = df['country'].ffill()
df['date_added'] = df['date_added'].ffill()

# %%
df.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            1
# country         0
# date_added      0
# release_year    0
# rating          4
# duration        3
# listed_in       0
# description     0
# dtype: int64

# %%
df['cast'] = df['cast'].bfill()
df['rating'] = df['rating'].bfill()
df['duration'] = df['duration'].bfill()

# %%
df.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %% [markdown]
# ## See the Statistics values

# %%
df.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %% [markdown]
# ## Movies vs TV Shows

# %%
df['type'].value_counts() #Insight: Which content is more?
# Out:
# type
# Movie      6131
# TV Show    2676
# Name: count, dtype: int64

# %% [markdown]
# ## Top countries producing content

# %%
df['country'].value_counts().head(10) #Insight: Which country produces most Netflix content?
# Out:
# country
# United States     3095
# India             1071
# United Kingdom     465
# Japan              270
# South Korea        218
# Canada             189
# Spain              161
# France             136
# Nigeria            124
# Mexico             116
# Name: count, dtype: int64

# %% [markdown]
# ## Content added over time

# %%
df['release_year'].value_counts().sort_index() #Insight: Growth of Netflix content
# Out:
# release_year
# 1925       1
# 1942       2
# 1943       3
# 1944       3
# 1945       4
#         ...
# 2017    1032
# 2018    1147
# 2019    1030
# 2020     953
# 2021     592
# Name: count, Length: 74, dtype: int64

# %% [markdown]
# ## Ratings distribution

# %%
df['rating'].value_counts() #Insight: Most common rating (TV-MA, PG, etc.)
# Out:
# rating
# TV-MA       3207
# TV-14       2160
# TV-PG        865
# R            800
# PG-13        490
# TV-Y7        335
# TV-Y         307
# PG           287
# TV-G         220
# NR            80
# G             41
# TV-Y7-FV       6
# NC-17          3
# UR             3
# 74 min         1
# 84 min         1
# 66 min         1
# Name: count, dtype: int64

# %% [markdown]
# ## Most common genres

# %%
df['listed_in'].value_counts().head(10) #Insight: Popular genres
# Out:
# listed_in
# Dramas, International Movies                        362
# Documentaries                                       359
# Stand-Up Comedy                                     334
# Comedies, Dramas, International Movies              274
# Dramas, Independent Movies, International Movies    252
# Kids' TV                                            220
# Children & Family Movies                            215
# Children & Family Movies, Comedies                  201
# Documentaries, International Movies                 186
# Dramas, International Movies, Romantic Movies       180
# Name: count, dtype: int64

# %% [markdown]
# ## Movies duration analysis

# %%
df['duration'].value_counts().head()
# Out:
# duration
# 1 Season     1794
# 2 Seasons     425
# 3 Seasons     199
# 90 min        152
# 94 min        146
# Name: count, dtype: int64

# %% [markdown]
# ## Most frequent directors

# %%
df['director'].value_counts().head(10)
# Out:
# director
# Marcus Raboy              32
# Raúl Campos, Jan Suter    23
# Jay Karas                 22
# Rajiv Chilaka             22
# Steve McLean              20
# Youssef Chahine           17
# Suhas Kadav               17
# Cathy Garcia-Molina       16
# Jay Chapman               15
# Ryan Polito               15
# Name: count, dtype: int64

# %% [markdown]
# ## Year with most releases

# %%
df['release_year'].mode()
# Out:
# 0    2018
# Name: release_year, dtype: int64

# %% [markdown]
# # Data Visualization

# %% [markdown]
# ### Bar Chart (Movies vs TV Shows)

# %%
import matplotlib.pyplot as plt

df['type'].value_counts().plot(kind='bar')
plt.title("Movies vs TV Shows")
plt.xlabel("Type")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ### Pie Chart (Content Type)

# %%
df['type'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title("Content Distribution")
plt.show()

# %% [markdown]
# ### Trend over years

# %%
df['release_year'].value_counts().sort_index().plot()
plt.title("Content Growth Over Years")
plt.xlabel("Year")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ### Top 10 Countries (Bar Chart)

# %%
df['country'].value_counts().head(10).plot(kind='bar')
plt.title("Top 10 Countries")
plt.show()
